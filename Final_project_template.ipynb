# %% [markdown]
# # Title: Hello World NLP Project
#
# #### Members' Names or Individual's Name: (Name should match D2L, do not write your nick names)
#
# ####  Emails:

# %% [markdown]
# # Introduction:
#
# #### Problem Description:
#
# Write description here
#
# #### Context of the Problem:
#
# Write why this problem is important here
#
# #### Limitation About other Approaches:
#
# Write a sentence or two about limitations of prior appraoches (you will provide their details in the background section next)
#
# #### Solution:
#
# How the method you are discussing is going to solve it today. Wrtie couple of sentences only.

# %% [markdown]
# # Background
#
# Explain the related work using the following table
#
# | Reference |Explanation |  Dataset/Input |Weakness
# | --- | --- | --- | --- |
# | Tom et al. [1] | They trained a BERT based transformer to predict answers from the passage of a question| SQUAD dataset for QA | Only 80% accuracy
# | George et al. [2] | They trained a attention based sequence to sequence model using LSTM to predict answers from the passage of a question| SQUAD V2 dataset for QA | High accuracy but poor on unkown answers
#
#
# The last row in this table should be about the method discussed in this paper (If you can't find the weakenss of this method then write about the future improvement, see the future work section of the paper)

# %% [markdown]
# # Methodology
#
# Provide details of the method that you are implementing in the next section with figure(s).  Your methodology will be just one method discussed in one of the paper of your choice; it can be a merger or a simplified version of the papers. To avoid any confusion, do not present multiple methods, just one unified method as you will implement in the next section.
#
# For figures you can use this tag:
#
# ![Alternate text ](Figure.png "Title of the figure, location is simply the directory of the notebook")

# %% [markdown]
# # Implementation
#
# In this section, you will provide the code and its explanation. You may have to create more cells after this. (To keep the Notebook clean, do not display debugging output or thousands of print statements from hundreds of epochs. Make sure it is readable for others by reviewing it yourself carefully.)

# %%
# Install the required packages

# !pip install -r requirements.txt
# Out:
# Collecting google-cloud-aiplatform (from -r requirements.txt (line 1))
#   Downloading google_cloud_aiplatform-1.45.0-py2.py3-none-any.whl.metadata (28 kB)
# Collecting google-cloud-pipeline-components (from -r requirements.txt (line 2))
#   Downloading google_cloud_pipeline_components-2.12.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting kfp (from -r requirements.txt (line 3))
#   Downloading kfp-2.7.0.tar.gz (441 kB)
#      ---------------------------------------- 0.0/441.8 kB ? eta -:--:--
#      ---------- --------------------------- 122.9/441.8 kB 2.4 MB/s eta 0:00:01
#      --------------------------------- ---- 389.1/441.8 kB 4.8 MB/s eta 0:00:01
#      -------------------------------------- 441.8/441.8 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gcloud (from -r requirements.txt (line 4))
#   Downloading gcloud-0.18.3.tar.gz (454 kB)
#      ---------------------------------------- 0.0/454.4 kB ? eta -:--:--
#      ------------------------------------- 454.4/454.4 kB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading google_api_core-2.18.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting google-auth<3.0.0dev,>=2.14.1 (from google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.0 (from google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 (from google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading protobuf-4.25.3-cp39-cp39-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: packaging>=14.3 in c:\users\rosha\anaconda3\envs\nlp-project\lib\site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (24.0)
# Collecting google-cloud-storage<3.0.0dev,>=1.32.0 (from google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading google_cloud_storage-2.16.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Collecting google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 (from google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading google_cloud_bigquery-3.19.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting google-cloud-resource-manager<3.0.0dev,>=1.3.3 (from google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading google_cloud_resource_manager-1.12.3-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting shapely<3.0.0dev (from google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading shapely-2.0.3-cp39-cp39-win_amd64.whl.metadata (7.2 kB)
# Collecting pydantic<3 (from google-cloud-aiplatform->-r requirements.txt (line 1))
#   Using cached pydantic-2.6.4-py3-none-any.whl.metadata (85 kB)
# Collecting docstring-parser<1 (from google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting Jinja2<4,>=3.1.2 (from google-cloud-pipeline-components->-r requirements.txt (line 2))
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting click<9,>=8.0.0 (from kfp->-r requirements.txt (line 3))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting kfp-pipeline-spec==0.3.0 (from kfp->-r requirements.txt (line 3))
#   Downloading kfp_pipeline_spec-0.3.0-py3-none-any.whl.metadata (329 bytes)
# Collecting kfp-server-api<2.1.0,>=2.0.0 (from kfp->-r requirements.txt (line 3))
#   Downloading kfp-server-api-2.0.5.tar.gz (63 kB)
#      ---------------------------------------- 0.0/63.4 kB ? eta -:--:--
#      ---------------------------------------- 63.4/63.4 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting kubernetes<27,>=8.0.0 (from kfp->-r requirements.txt (line 3))
#   Downloading kubernetes-26.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting PyYAML<7,>=5.3 (from kfp->-r requirements.txt (line 3))
#   Using cached PyYAML-6.0.1-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# Collecting requests-toolbelt<1,>=0.8.0 (from kfp->-r requirements.txt (line 3))
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl.metadata (14 kB)
# Collecting tabulate<1,>=0.8.6 (from kfp->-r requirements.txt (line 3))
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting urllib3<2.0.0 (from kfp->-r requirements.txt (line 3))
#   Using cached urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
# Collecting httplib2>=0.9.1 (from gcloud->-r requirements.txt (line 4))
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting googleapis-common-protos (from gcloud->-r requirements.txt (line 4))
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting oauth2client>=2.0.1 (from gcloud->-r requirements.txt (line 4))
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: six in c:\users\rosha\anaconda3\envs\nlp-project\lib\site-packages (from gcloud->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: colorama in c:\users\rosha\anaconda3\envs\nlp-project\lib\site-packages (from click<9,>=8.0.0->kfp->-r requirements.txt (line 3)) (0.4.6)
# Collecting requests<3.0.0.dev0,>=2.18.0 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading grpcio-1.62.1-cp39-cp39-win_amd64.whl.metadata (4.2 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading grpcio_status-1.62.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting google-cloud-core<3.0.0dev,>=1.6.0 (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media<3.0dev,>=0.6.0 (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading google_resumable_media-2.7.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in c:\users\rosha\anaconda3\envs\nlp-project\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->-r requirements.txt (line 1)) (2.9.0)
# Collecting grpc-google-iam-v1<1.0.0dev,>=0.12.4 (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading grpc_google_iam_v1-0.13.0-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Downloading google_crc32c-1.5.0-cp39-cp39-win_amd64.whl.metadata (2.3 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2>=0.9.1->gcloud->-r requirements.txt (line 4))
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2<4,>=3.1.2->google-cloud-pipeline-components->-r requirements.txt (line 2))
#   Using cached MarkupSafe-2.1.5-cp39-cp39-win_amd64.whl.metadata (3.1 kB)
# Collecting certifi (from kfp-server-api<2.1.0,>=2.0.0->kfp->-r requirements.txt (line 3))
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\rosha\anaconda3\envs\nlp-project\lib\site-packages (from kubernetes<27,>=8.0.0->kfp->-r requirements.txt (line 3)) (68.2.2)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes<27,>=8.0.0->kfp->-r requirements.txt (line 3))
#   Downloading websocket_client-1.7.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting requests-oauthlib (from kubernetes<27,>=8.0.0->kfp->-r requirements.txt (line 3))
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting pyasn1>=0.1.7 (from oauth2client>=2.0.1->gcloud->-r requirements.txt (line 4))
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic<3->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Using cached pydantic_core-2.16.3-cp39-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\rosha\anaconda3\envs\nlp-project\lib\site-packages (from pydantic<3->google-cloud-aiplatform->-r requirements.txt (line 1)) (4.10.0)
# Collecting numpy<2,>=1.14 (from shapely<3.0.0dev->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl.metadata (61 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Using cached charset_normalizer-3.3.2-cp39-cp39-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->-r requirements.txt (line 1))
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes<27,>=8.0.0->kfp->-r requirements.txt (line 3))
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading google_cloud_aiplatform-1.45.0-py2.py3-none-any.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------- ----------------------- 1.8/4.3 MB 38.3 MB/s eta 0:00:01
#    ------------------------------------- -- 4.0/4.3 MB 42.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 38.7 MB/s eta 0:00:00
# Downloading google_cloud_pipeline_components-2.12.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 45.5 MB/s eta 0:00:00
# Downloading kfp_pipeline_spec-0.3.0-py3-none-any.whl (12 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading google_api_core-2.18.0-py3-none-any.whl (138 kB)
#    ---------------------------------------- 0.0/138.3 kB ? eta -:--:--
#    ---------------------------------------- 138.3/138.3 kB 8.5 MB/s eta 0:00:00
# Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#    ---------------------------------------- 0.0/189.2 kB ? eta -:--:--
#    --------------------------------------- 189.2/189.2 kB 11.9 MB/s eta 0:00:00
# Downloading google_cloud_bigquery-3.19.0-py2.py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    --------------------------------------- 232.6/232.6 kB 14.8 MB/s eta 0:00:00
# Downloading google_cloud_resource_manager-1.12.3-py2.py3-none-any.whl (333 kB)
#    ---------------------------------------- 0.0/333.7 kB ? eta -:--:--
#    --------------------------------------- 333.7/333.7 kB 20.2 MB/s eta 0:00:00
# Downloading google_cloud_storage-2.16.0-py2.py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/125.6 kB ? eta -:--:--
#    ---------------------------------------- 125.6/125.6 kB 7.7 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#    ---------------------------------------- 0.0/229.1 kB ? eta -:--:--
#    --------------------------------------- 229.1/229.1 kB 14.6 MB/s eta 0:00:00
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#    ---------------------------------------- 96.9/96.9 kB 5.8 MB/s eta 0:00:00
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Downloading kubernetes-26.1.0-py2.py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 44.9 MB/s eta 0:00:00
# Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.2 kB ? eta -:--:--
#    ---------------------------------------- 98.2/98.2 kB ? eta 0:00:00
# Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.8 kB ? eta -:--:--
#    ---------------------------------------- 48.8/48.8 kB ? eta 0:00:00
# Downloading protobuf-4.25.3-cp39-cp39-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    ---------------------------------------- 413.4/413.4 kB ? eta 0:00:00
# Using cached pydantic-2.6.4-py3-none-any.whl (394 kB)
# Using cached pydantic_core-2.16.3-cp39-none-win_amd64.whl (1.9 MB)
# Using cached PyYAML-6.0.1-cp39-cp39-win_amd64.whl (152 kB)
# Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# Downloading shapely-2.0.3-cp39-cp39-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 31.1 MB/s eta 0:00:00
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.5.0-cp39-cp39-win_amd64.whl (27 kB)
# Downloading google_resumable_media-2.7.0-py2.py3-none-any.whl (80 kB)
#    ---------------------------------------- 0.0/80.6 kB ? eta -:--:--
#    ---------------------------------------- 80.6/80.6 kB 4.7 MB/s eta 0:00:00
# Downloading grpc_google_iam_v1-0.13.0-py2.py3-none-any.whl (25 kB)
# Downloading grpcio-1.62.1-cp39-cp39-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----------------------------- ---------- 2.8/3.8 MB 59.7 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 48.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 40.4 MB/s eta 0:00:00
# Downloading grpcio_status-1.62.1-py3-none-any.whl (14 kB)
# Using cached MarkupSafe-2.1.5-cp39-cp39-win_amd64.whl (17 kB)
# Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.3 kB ? eta -:--:--
#    ---------------------------------------- 85.3/85.3 kB ? eta 0:00:00
# Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#    ---------------------------------------- 0.0/181.2 kB ? eta -:--:--
#    --------------------------------------- 181.2/181.2 kB 11.4 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB ? eta 0:00:00
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Downloading websocket_client-1.7.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.5 kB ? eta -:--:--
#    ---------------------------------------- 58.5/58.5 kB ? eta 0:00:00
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached charset_normalizer-3.3.2-cp39-cp39-win_amd64.whl (100 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Building wheels for collected packages: kfp, gcloud, kfp-server-api
#   Building wheel for kfp (setup.py): started
#   Building wheel for kfp (setup.py): finished with status 'done'
#   Created wheel for kfp: filename=kfp-2.7.0-py3-none-any.whl size=610438 sha256=7a246e4580c6c819bbbc95c28c9ac309656099df452e0fa1ccda7a5abf79edd8
#   Stored in directory: c:\users\rosha\appdata\local\pip\cache\wheels\6b\21\04\3a90a57cfed7fb3b132d75ef1617fdeaa85916b04551d5369d
#   Building wheel for gcloud (setup.py): started
#   Building wheel for gcloud (setup.py): finished with status 'done'
#   Created wheel for gcloud: filename=gcloud-0.18.3-py3-none-any.whl size=602980 sha256=c578293804eee1014963276700863882b359be7f73856a1df37adcdb0de201c3
#   Stored in directory: c:\users\rosha\appdata\local\pip\cache\wheels\b1\57\b6\9ba8c7c51c29b2de31a82e41ace31048bb4b814974d215bb22
#   Building wheel for kfp-server-api (setup.py): started
#   Building wheel for kfp-server-api (setup.py): finished with status 'done'
#   Created wheel for kfp-server-api: filename=kfp_server_api-2.0.5-py3-none-any.whl size=114745 sha256=58f3fbf90de6864b1db1d80cb62f5acf5743974f23650d21028da6dcff599ca5
#   Stored in directory: c:\users\rosha\appdata\local\pip\cache\wheels\a6\c9\de\9f6964cdffc4d454c0a96d34f9b5ea5e51fc3224ec379222ff
# Successfully built kfp gcloud kfp-server-api
# Installing collected packages: websocket-client, urllib3, tabulate, PyYAML, pyparsing, pydantic-core, pyasn1, protobuf, oauthlib, numpy, MarkupSafe, idna, grpcio, google-crc32c, docstring-parser, click, charset-normalizer, certifi, cachetools, annotated-types, shapely, rsa, requests, pydantic, pyasn1-modules, proto-plus, kfp-server-api, kfp-pipeline-spec, Jinja2, httplib2, googleapis-common-protos, google-resumable-media, requests-toolbelt, requests-oauthlib, oauth2client, grpcio-status, google-auth, kubernetes, grpc-google-iam-v1, google-api-core, gcloud, google-cloud-core, google-cloud-storage, google-cloud-resource-manager, google-cloud-bigquery, kfp, google-cloud-aiplatform, google-cloud-pipeline-components
# Successfully installed Jinja2-3.1.3 MarkupSafe-2.1.5 PyYAML-6.0.1 annotated-types-0.6.0 cachetools-5.3.3 certifi-2024.2.2 charset-normalizer-3.3.2 click-8.1.7 docstring-parser-0.16 gcloud-0.18.3 google-api-core-2.18.0 google-auth-2.29.0 google-cloud-aiplatform-1.45.0 google-cloud-bigquery-3.19.0 google-cloud-core-2.4.1 google-cloud-pipeline-components-2.12.0 google-cloud-resource-manager-1.12.3 google-cloud-storage-2.16.0 google-crc32c-1.5.0 google-resumable-media-2.7.0 googleapis-common-protos-1.63.0 grpc-google-iam-v1-0.13.0 grpcio-1.62.1 grpcio-status-1.62.1 httplib2-0.22.0 idna-3.6 kfp-2.7.0 kfp-pipeline-spec-0.3.0 kfp-server-api-2.0.5 kubernetes-26.1.0 numpy-1.26.4 oauth2client-4.1.3 oauthlib-3.2.2 proto-plus-1.23.0 protobuf-4.25.3 pyasn1-0.6.0 pyasn1-modules-0.4.0 pydantic-2.6.4 pydantic-core-2.16.3 pyparsing-3.1.2 requests-2.31.0 requests-oauthlib-2.0.0 requests-toolbelt-0.10.1 rsa-4.9 shapely-2.0.3 tabulate-0.9.0 urllib3-1.26.18 websocket-client-1.7.0

# %%
# Code cells
PROJECT_ID = "edplato-ds-dev"
# Out:
# Hello

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="D:\TMU\Winter Term-2023\NLP Project\nlp-project-rlhf\keys\hcp-key.json"
# Out:
#   Cell In[9], line 2
#     os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="D:\TMU\Winter Term-2023\NLP Project\nlp-project-rlhf\keys\hcp-key.json"
#                                                                                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 23-24: malformed \N character escape

# %%
# Set the project id
# !gcloud config set project {PROJECT_ID}
# Out:
# 'gcloud' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Conclusion and Future Direction
#
# Write what you have learnt in this project. In particular, write few sentences about the results and their limitations, how they can be extended in future. Make sure your own inference/learnings are depicted here.

# %% [markdown]
# # References:
#
# [1]:  Authors names, title of the paper, Conference Name,Year, page number (iff available)
#
# [2]:  Author names, title of the paper, Journal Name,Journal Vol, Issue Num, Year, page number (iff available)
